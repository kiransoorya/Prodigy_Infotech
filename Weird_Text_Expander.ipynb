# %%
# !pip install -q transformers

from transformers import AutoModelForCausalLM, AutoTokenizer

import torch

torch_device = "cuda" if torch.cuda.is_available() else "cpu"

tokenizer = AutoTokenizer.from_pretrained("gpt2")

model = AutoModelForCausalLM.from_pretrained("gpt2", pad_token_id=tokenizer.eos_token_id).to(torch_device)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
user_prompt = input("Enter text to generate prompt:")
max_words = int(input("Enter max words:"))
max_sequences = int(input("Enter max sequences:"))
# Out:
# Enter text to generate prompt:Today's lecture was about different types of rocks in geology
# Enter max words:500
# Enter max sequences:10

# %%
model_inputs = tokenizer(user_prompt, return_tensors='pt').to(torch_device)

from transformers import set_seed

set_seed(42)

sample_outputs = model.generate(
    **model_inputs,
    max_new_tokens=max_words,
    do_sample=True,
    top_k=50,
    top_p=0.95,
    no_repeat_ngram_size=2,
    temperature=.4,
    num_return_sequences=max_sequences,
)

print("Generated Expansions Based On Context:\n" + 100 * '-')

samples = [
    tokenizer.decode(sample_output, skip_special_tokens=True)
    for sample_output in sample_outputs
]

result = max(samples,key=len)

last_full_stop_index = result.rfind('.')

if last_full_stop_index != -1:
    result = result[:last_full_stop_index + 1]

print(result)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generated Expansions Based On Context:
# ----------------------------------------------------------------------------------------------------
# Today's lecture was about different types of rocks in geology, and it was a great way to get a better understanding of the different kinds of rock. I'm really pleased to be able to share this with you, because it's really important to understand the science of how rocks are formed, how they interact with each other, what they do, etc.
#
# I think this is a really good opportunity to talk about the role of geologists in the Earth's history. It's a very important topic, but it also has a lot of implications for how we think about Earth and how it evolves. And I think it is important that we understand how geologic processes work, as well as how the rocks that are in our bodies are made. So I'd like to take this opportunity, for example, to say that there are many different forms of life on Earth. But I also think that it has to do with how life is formed in different geological environments. We're living in a world where there is so much variation in how many rocks and rocks we have, so many ways to make life. The way we make it, the way that life forms, is very different from how things are produced. There are a number of different ways that different rocks can make different things, different processes, that can produce different results. That's what I would like you to focus on. Because it would be very interesting to see how different rock types interact, especially in relation to the other types. You know, there's so little information available about what different minerals are, or what kinds are different, which is why I want to give you a little bit of information about how these different mineral types are distributed in Earth, with respect to how those different different geologically different formations are found in other places. Let's get started. Now, I know that I have to go back to a previous lecture, where I said that the whole idea of Earth as a system of geological formations is not only a good idea, it actually is the most important idea in science. This is because the system that is created in this system is actually very complex. If you look at the history of our planet, you'll see that for a long time there was very little variation. Then, after a while, when the ice sheets started to melt, we started seeing a huge change in ice cover. When we get to that point, things start to change, from what we would call a'magnificent' change.
